# %% [markdown]
# #### Week 5 Challenge
# ##### Task-1 Data Ingestion and  Data Preprocessing

# %%
import sys
import os

# Define the paths for 'scripts' and 'src' directories
src_dir = "C:/Users/ibsan/Desktop/TenX/week-5/src"
data_dir = r'C:/Users/ibsan/Desktop/TenX/week-5/data/processed_data'

# Add these directories to the Python path if not already present
if src_dir not in sys.path:
    sys.path.append(src_dir)

if data_dir not in sys.path:
    sys.path.append(data_dir)

# Define the input and output file paths
input_file = os.path.join("C:/Users/ibsan/Desktop/TenX/week-5/data", 'telegram_data.csv')  # Path to the scraped data
output_file = os.path.join(data_dir, 'cleaned_telegram_data.csv')  # Path to save the cleaned data
file = os.path.join(data_dir, 'telegram_data_cleaned.csv')  # Path to save the cleaned data

# %%
from data_preprocessing import  preprocess_telegram_data,plot

# %%
cleaned_data = preprocess_telegram_data(input_file)
preprocess_telegram_data(input_file)
# Out:
# Checking for NaN values in the 'Message' column:
# Number of NaN values in 'Message' column: 4779
# Cleaned data saved successfully to E:\DS+ML\AIM3\Practice\Week-5\scripts\telegram_data_cleaned.csv
# Checking for NaN values in the 'Message' column:
# Number of NaN values in 'Message' column: 4779
# Cleaned data saved successfully to E:\DS+ML\AIM3\Practice\Week-5\scripts\telegram_data_cleaned.csv
#            Channel Title Channel Username    ID                       Date  \
# 0         Zemen Express®    @ZemenExpress  6043  2025-01-18 20:28:12+00:00
# 1         Zemen Express®    @ZemenExpress  6042  2025-01-18 12:41:55+00:00
# 2         Zemen Express®    @ZemenExpress  6041  2025-01-18 12:41:43+00:00
# 3         Zemen Express®    @ZemenExpress  6040  2025-01-18 08:21:09+00:00
# 6         Zemen Express®    @ZemenExpress  6037  2025-01-18 08:20:44+00:00
# ...                  ...              ...   ...                        ...
# ...

# %%
plot(cleaned_data)
# Out:
# Font 'Abyssinica SIL' registered successfully.
